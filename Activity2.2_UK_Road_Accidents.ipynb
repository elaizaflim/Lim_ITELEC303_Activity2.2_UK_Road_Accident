# %% [markdown]
# <h1> Activity 2: UK ACCIDENT ANALYTICS</h1>
# <h2> Elaiza F. Lim</h2>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
accidents = pd.read_csv('uk_road_Accident.csv')

# %%
accidents
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 0       200701BS64157           Serious      5/6/2019  51.506187
# 1       200701BS65737           Serious      2/7/2019  51.495029
# 2       200701BS66127           Serious    26-08-2019  51.517715
# 3       200701BS66128           Serious    16-08-2019  51.495478
# 4       200701BS66837            Slight      3/9/2019  51.488576
# ...               ...               ...           ...        ...
# 660674  201091NM01760            Slight    18-02-2022  57.374005
# 660675  201091NM01881            Slight    21-02-2022  57.232273
# 660676  201091NM01935            Slight    23-02-2022  57.585044
# 660677  201091NM01964           Serious    23-02-2022  57.214898
# 660678  201091NM02142           Serious    28-02-2022  57.575210
#
#                    Light_Conditions           District Area  Longitude  \
# 0             Darkness - lights lit  Kensington and Chelsea  -0.209082
# ...

# %%
accidents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660679 entries, 0 to 660678
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Index                    660679 non-null  object
#  1   Accident_Severity        660679 non-null  object
#  2   Accident Date            660679 non-null  object
#  3   Latitude                 660654 non-null  float64
#  4   Light_Conditions         660679 non-null  object
#  5   District Area            660679 non-null  object
#  6   Longitude                660653 non-null  float64
#  7   Number_of_Casualties     660679 non-null  int64
#  8   Number_of_Vehicles       660679 non-null  int64
#  9   Road_Surface_Conditions  659953 non-null  object
#  10  Road_Type                656159 non-null  object
#  11  Urban_or_Rural_Area      660664 non-null  object
#  12  Weather_Conditions       646551 non-null  object
# ...

# %%
accidents.describe().T
# Out:
#                          count       mean       std        min        25%  \
# Latitude              660654.0  52.553866  1.406922  49.914430  51.490690
# Longitude             660653.0  -1.431210  1.383330  -7.516225  -2.332291
# Number_of_Casualties  660679.0   1.357040  0.824847   1.000000   1.000000
# Number_of_Vehicles    660679.0   1.831255  0.715269   1.000000   1.000000
#
#                             50%        75%        max
# Latitude              52.315641  53.453452  60.757544
# Longitude             -1.411667  -0.232869   1.762010
# Number_of_Casualties   1.000000   1.000000  68.000000
# Number_of_Vehicles     2.000000   2.000000  32.000000

# %%
accidents.dtypes
# Out:
# Index                       object
# Accident_Severity           object
# Accident Date               object
# Latitude                   float64
# Light_Conditions            object
# District Area               object
# Longitude                  float64
# Number_of_Casualties         int64
# Number_of_Vehicles           int64
# Road_Surface_Conditions     object
# Road_Type                   object
# Urban_or_Rural_Area         object
# Weather_Conditions          object
# Vehicle_Type                object
# dtype: object

# %%
accidents.isnull().sum()
# Out:
# Index                          0
# Accident_Severity              0
# Accident Date                  0
# Latitude                      25
# Light_Conditions               0
# District Area                  0
# Longitude                     26
# Number_of_Casualties           0
# Number_of_Vehicles             0
# Road_Surface_Conditions      726
# Road_Type                   4520
# Urban_or_Rural_Area           15
# Weather_Conditions         14128
# Vehicle_Type                   0
# dtype: int64

# %%
accidents.Accident_Severity
# Out:
# 0         Serious
# 1         Serious
# 2         Serious
# 3         Serious
# 4          Slight
#            ...
# 660674     Slight
# 660675     Slight
# 660676     Slight
# 660677    Serious
# 660678    Serious
# Name: Accident_Severity, Length: 660679, dtype: object

# %%
accidents.Light_Conditions
# Out:
# 0               Darkness - lights lit
# 1                            Daylight
# 2         Darkness - lighting unknown
# 3                            Daylight
# 4               Darkness - lights lit
#                      ...
# 660674                       Daylight
# 660675         Darkness - no lighting
# 660676                       Daylight
# 660677         Darkness - no lighting
# 660678                       Daylight
# Name: Light_Conditions, Length: 660679, dtype: object

# %%
accidents.Vehicle_Type
# Out:
# 0                                          Car
# 1                                          Car
# 2                        Taxi/Private hire car
# 3         Bus or coach (17 or more pass seats)
# 4                                Other vehicle
#                           ...
# 660674                                     Car
# 660675                                     Car
# 660676                                     Car
# 660677                   Motorcycle over 500cc
# 660678                                     Car
# Name: Vehicle_Type, Length: 660679, dtype: object

# %%
accidents.Weather_Conditions
# Out:
# 0            Fine no high winds
# 1         Raining no high winds
# 2                           NaN
# 3            Fine no high winds
# 4                           NaN
#                   ...
# 660674       Fine no high winds
# 660675       Fine no high winds
# 660676       Fine no high winds
# 660677       Fine no high winds
# 660678    Snowing no high winds
# Name: Weather_Conditions, Length: 660679, dtype: object

# %%
accidents.head()
# Out:
#            Index Accident_Severity Accident Date   Latitude  \
# 0  200701BS64157           Serious      5/6/2019  51.506187
# 1  200701BS65737           Serious      2/7/2019  51.495029
# 2  200701BS66127           Serious    26-08-2019  51.517715
# 3  200701BS66128           Serious    16-08-2019  51.495478
# 4  200701BS66837            Slight      3/9/2019  51.488576
#
#               Light_Conditions           District Area  Longitude  \
# 0        Darkness - lights lit  Kensington and Chelsea  -0.209082
# 1                     Daylight  Kensington and Chelsea  -0.173647
# 2  Darkness - lighting unknown  Kensington and Chelsea  -0.210215
# 3                     Daylight  Kensington and Chelsea  -0.202731
# 4        Darkness - lights lit  Kensington and Chelsea  -0.192487
#
#    Number_of_Casualties  Number_of_Vehicles Road_Surface_Conditions  \
# 0                     1                   2                     Dry
# ...

# %%
accidents.columns
# Out:
# Index(['Index', 'Accident_Severity', 'Accident Date', 'Latitude',
#        'Light_Conditions', 'District Area', 'Longitude',
#        'Number_of_Casualties', 'Number_of_Vehicles', 'Road_Surface_Conditions',
#        'Road_Type', 'Urban_or_Rural_Area', 'Weather_Conditions',
#        'Vehicle_Type'],
#       dtype='object')

# %%
# Creating weights that are opposite to the weights of target
weights = np.where(df['Accident_Severity'] == 'Slight', .2, .8)

#Sampling only 30% of the data with new weights  
df = df.sample(frac=0.3, replace=True, weights=weights)
print(df.shape)
#df.Accident_Severity.value_counts(normalize=True)
# Out:
# (198204, 14)

# %%
#Distribution of sample data by targets

ax = sns.countplot(x = df.Accident_Severity ,palette="Set2")
sns.set(font_scale=1.5)
ax.set_xlabel(' ')
ax.set_ylabel(' ')
fig = plt.gcf()
fig.set_size_inches(8,4)
for p in ax.patches:
    ax.annotate('{:.2f}%'.format(100*p.get_height()/len(df.Accident_Severity)), (p.get_x()+ 0.3, p.get_height()+10000))

plt.title('Light_Conditions',)
plt.xlabel('Accident Severity')
plt.ylabel('Latitude')
plt.show()
# Out:
# C:\Users\there\AppData\Local\Temp\ipykernel_13256\1226631651.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x = df.Accident_Severity ,palette="Set2")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 3 = Slight, 1 = Fatal, 2 = Serious
acc_slight = df['Accident_Severity'] == 3
acc_severe = df['Accident_Severity'] != 3

plt.figure(figsize=(14, 5))

sns.kdeplot(
    df['Number_of_Casualties'][acc_slight],
    shade=True,
    color='blue',
    label='Slight'
)
sns.kdeplot(
    df['Number_of_Casualties'][acc_severe],
    shade=True,
    color='red',
    label='Severe'
).set_xlim(0, 20)

plt.title('Number_of_Vehicles by Accident Severity')
plt.xlabel('Number of Casualties')
plt.ylabel('Light_Conditions')
plt.legend()
plt.show()
# Out:
# C:\Users\there\AppData\Local\Temp\ipykernel_13256\1197346649.py:10: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(
# C:\Users\there\AppData\Local\Temp\ipykernel_13256\1197346649.py:16: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(

# %%
plt.figure(figsize=(14,5))

sns.kdeplot(df.Number_of_Vehicles[acc_slight],shade=True,color='Blue', label='Slight').set_xlim(0,20)
sns.kdeplot(df.Number_of_Vehicles[acc_severe],shade=True,color='Green', label='Severe').set_xlim(0,20)

plt.title('Longitude')
plt.show()

#print("we can see distribution between failed (under 2000), and successful (bigger the 2000)")
# Out:
# C:\Users\there\AppData\Local\Temp\ipykernel_13256\310863994.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df.Number_of_Vehicles[acc_slight],shade=True,color='Blue', label='Slight').set_xlim(0,20)
# C:\Users\there\AppData\Local\Temp\ipykernel_13256\310863994.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df.Number_of_Vehicles[acc_severe],shade=True,color='Green', label='Severe').set_xlim(0,20)

# %%
print(df.head())
print(df.columns.tolist())
print(df['Accident_Severity'].value_counts())
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 273152       2.01E+12            Slight    22-02-2020  52.665946
# 535586  201001WW50520            Slight    15-07-2022  51.429677
# 353067  200901BS70424            Slight    27-07-2021  51.495208
# 507091       2.01E+12            Slight     12/4/2021  56.482868
# 464273  200943S057049            Slight     12/4/2021  52.101796
#
#              Light_Conditions           District Area  Longitude  \
# 273152               Daylight               Charnwood  -1.129162
# 535586               Daylight              Wandsworth  -0.163739
# 353067  Darkness - lights lit  Kensington and Chelsea  -0.179403
# 507091               Daylight             Dundee City  -3.001307
# 464273               Daylight           Milton Keynes  -0.692113
#
#         Number_of_Casualties  Number_of_Vehicles Road_Surface_Conditions  \
# 273152                     1                   1                     Dry
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Index', 'Accident_Severity', 'Accident Date', 'Latitude', 'Light_Conditions', 'District Area', 'Longitude', 'Number_of_Casualties', 'Number_of_Vehicles', 'Road_Surface_Conditions', 'Road_Type', 'Urban_or_Rural_Area', 'Weather_Conditions', 'Vehicle_Type']

# %%
df.columns = df.columns.str.strip()

# %%
# Make a copy of your original df
accident_severity_df = df.copy()

# Drop the columns that are not impactful
accident_severity_df.drop(['Light_Conditions', 'Weather_Conditions'], axis=1, inplace=True)

# Now you can inspect it
accident_severity_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 198204 entries, 273152 to 305740
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Index                    198204 non-null  object
#  1   Accident_Severity        198204 non-null  object
#  2   Accident Date            198204 non-null  object
#  3   Latitude                 198198 non-null  float64
#  4   District Area            198204 non-null  object
#  5   Longitude                198198 non-null  float64
#  6   Number_of_Casualties     198204 non-null  int64
#  7   Number_of_Vehicles       198204 non-null  int64
#  8   Road_Surface_Conditions  198011 non-null  object
#  9   Road_Type                196950 non-null  object
#  10  Urban_or_Rural_Area      198199 non-null  object
#  11  Vehicle_Type             198204 non-null  object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 19.7+ MB

# %%
print(accident_severity_df.columns.tolist())
# Out:
# ['Index', 'Accident_Severity', 'Accident Date', 'Latitude', 'District Area', 'Longitude', 'Number_of_Casualties', 'Number_of_Vehicles', 'Road_Surface_Conditions', 'Road_Type', 'Urban_or_Rural_Area', 'Vehicle_Type']

# %% [markdown]
# <h1> INSIGHT 1</h1>

# %%
severity_counts = accidents['Accident_Severity'].value_counts()
severity_counts
# Out:
# Accident_Severity
# Slight     563801
# Serious     88217
# Fatal        8661
# Name: count, dtype: int64

# %%
accidents.describe().T
# Out:
#                          count       mean       std        min        25%  \
# Latitude              660654.0  52.553866  1.406922  49.914430  51.490690
# Longitude             660653.0  -1.431210  1.383330  -7.516225  -2.332291
# Number_of_Casualties  660679.0   1.357040  0.824847   1.000000   1.000000
# Number_of_Vehicles    660679.0   1.831255  0.715269   1.000000   1.000000
#
#                             50%        75%        max
# Latitude              52.315641  53.453452  60.757544
# Longitude             -1.411667  -0.232869   1.762010
# Number_of_Casualties   1.000000   1.000000  68.000000
# Number_of_Vehicles     2.000000   2.000000  32.000000

# %%
accidents.Accident_Severity
# Out:
# 0         Serious
# 1         Serious
# 2         Serious
# 3         Serious
# 4          Slight
#            ...
# 660674     Slight
# 660675     Slight
# 660676     Slight
# 660677    Serious
# 660678    Serious
# Name: Accident_Severity, Length: 660679, dtype: object

# %%
accidents.Light_Conditions
# Out:
# 0               Darkness - lights lit
# 1                            Daylight
# 2         Darkness - lighting unknown
# 3                            Daylight
# 4               Darkness - lights lit
#                      ...
# 660674                       Daylight
# 660675         Darkness - no lighting
# 660676                       Daylight
# 660677         Darkness - no lighting
# 660678                       Daylight
# Name: Light_Conditions, Length: 660679, dtype: object

# %%
accidents.Vehicle_Type
# Out:
# 0                                          Car
# 1                                          Car
# 2                        Taxi/Private hire car
# 3         Bus or coach (17 or more pass seats)
# 4                                Other vehicle
#                           ...
# 660674                                     Car
# 660675                                     Car
# 660676                                     Car
# 660677                   Motorcycle over 500cc
# 660678                                     Car
# Name: Vehicle_Type, Length: 660679, dtype: object

# %%
accidents.Weather_Conditions
# Out:
# 0            Fine no high winds
# 1         Raining no high winds
# 2                           NaN
# 3            Fine no high winds
# 4                           NaN
#                   ...
# 660674       Fine no high winds
# 660675       Fine no high winds
# 660676       Fine no high winds
# 660677       Fine no high winds
# 660678    Snowing no high winds
# Name: Weather_Conditions, Length: 660679, dtype: object

# %% [markdown]
# <h1> INSIGHT 2 </h1>

# %%
light_conditions = accidents['Light_Conditions'].value_counts()
light_conditions
# Out:
# Light_Conditions
# Daylight                       484880
# Darkness - lights lit          129335
# Darkness - no lighting          37437
# Darkness - lighting unknown      6484
# Darkness - lights unlit          2543
# Name: count, dtype: int64

# %%
accidents['Accident Date'] = pd.to_datetime(accidents['Accident Date'], errors='coerce')
yearly_accidents = accidents['Accident Date'].dt.year.value_counts().sort_index()
yearly_accidents
# Out:
# Accident Date
# 2019.0    71867
# 2020.0    70163
# 2021.0    66172
# 2022.0    56805
# Name: count, dtype: int64

# %% [markdown]
# <h1> INSIGHT 3</h1>

# %%
avg_vehicles = accidents.groupby('Accident_Severity')['Number_of_Vehicles'].mean().reset_index(name='Avg_Vehicles')
avg_vehicles
# Out:
#   Accident_Severity  Avg_Vehicles
# 0             Fatal      1.786976
# 1           Serious      1.678327
# 2            Slight      1.855864

# %% [markdown]
# <h1> Insight 4</h1>

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()  # This creates the figure and axes
ax.set_xlabel('X-axis Label')
ax.set_ylabel('Y-axis Label')
fig = plt.gcf()  # Get current figure (optional, already stored in fig)
plt.show()

# %% [markdown]
# <h1> Insight 5</h1>

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [4, 5, 6])
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.show()

# %% [markdown]
# <h1> Insight 6: How many accidents occurred each year? </h1>

# %%
accidents['Year'] = accidents['Accident Date'].dt.year
yearly = accidents.groupby('Year').size().reset_index(name='Accident_Count')
yearly
# Out:
#      Year  Accident_Count
# 0  2019.0           71867
# 1  2020.0           70163
# 2  2021.0           66172
# 3  2022.0           56805

# %% [markdown]
# <h1> Insight 7: What is the average number of vehicles per district?</h1>

# %%
accidents.groupby('Urban_or_Rural_Area')['Number_of_Vehicles'].mean().reset_index(name='Avg_Vehicles')
# Out:
#   Urban_or_Rural_Area  Avg_Vehicles
# 0               Rural      1.866312
# 1         Unallocated      1.909091
# 2               Urban      1.811394

# %% [markdown]
# <h1> Insight 8: What is the average number of Accident Date?</h1>

# %%
accidents.groupby('Accident Date')['Number_of_Vehicles'].mean().reset_index(name='Avg_Vehicles')
# Out:
#     Accident Date  Avg_Vehicles
# 0      2019-01-01      1.644776
# 1      2019-01-02      1.816568
# 2      2019-01-03      1.793774
# 3      2019-01-04      1.795337
# 4      2019-01-05      1.927083
# ..            ...           ...
# 571    2022-12-08      1.876574
# 572    2022-12-09      1.790560
# 573    2022-12-10      1.862140
# 574    2022-12-11      1.872495
# 575    2022-12-12      1.795380
#
# [576 rows x 2 columns]

# %% [markdown]
# <h1> Insight 9: Which road surface condition is most common in accidents?</h1>

# %%
road_surface_counts = accidents['Road_Surface_Conditions'].value_counts()
road_surface_counts.plot(
    kind = 'bar',
    color = ['red','black','green','yellow','violet'],
    figsize = (8,5),
    title = 'Accident by Road Surface Condition'
)

plt.xlabel("Road Surface Condition")
plt.ylabel("Number of Accident")
plt.grid(axis='y', alpha=0.5)
plt.show()

# %% [markdown]
# <h1> Insight 10: Which vehicle type contributes most to fatal accidents?</h1>

# %%
vehicle_vs_severity = accidents.groupby(['Vehicle_Type','Accident_Severity']).size().unstack().fillna(0)
vehicle_vs_severity.sort_values("Fatal", ascending=False).head(10)
# Out:
# Accident_Severity                       Fatal  Serious    Slight
# Vehicle_Type
# Car                                    6577.0  66461.0  424954.0
# Van / Goods 3.5 tonnes mgw or under     467.0   4554.0   29139.0
# Motorcycle over 500cc                   339.0   3457.0   21861.0
# Bus or coach (17 or more pass seats)    325.0   3373.0   22180.0
# Goods 7.5 tonnes mgw and over           216.0   2321.0   14770.0
# Motorcycle 125cc and under              189.0   2031.0   13049.0
# Taxi/Private hire car                   155.0   1771.0   11368.0
# Motorcycle over 125cc and up to 500cc   105.0   1014.0    6537.0
# Motorcycle 50cc and under                95.0   1014.0    6494.0
# Other vehicle                            70.0    767.0    4800.0

# %% [markdown]
# <h1> Insight 11 </h1>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 3 = Slight, 1 = Fatal, 2 = Serious
acc_slight = accidents['Accident_Severity'] == 3
acc_severe = accidents['Accident_Severity'] != 3

plt.figure(figsize=(14, 5))

sns.kdeplot(
    accidents['Number_of_Casualties'][acc_slight],
    shade=True,
    color='blue',
    label='Slight'
)
sns.kdeplot(
    accidents['Number_of_Casualties'][acc_severe],
    shade=True,
    color='red',
    label='Severe'
).set_xlim(0, 20)

plt.title('Number_of_Vehicles by Accident Severity')
plt.xlabel('Number of Casualties')
plt.ylabel('Light_Conditions')
plt.legend()
plt.show()
# Out:
# C:\Users\there\AppData\Local\Temp\ipykernel_37480\1770313285.py:10: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(
# C:\Users\there\AppData\Local\Temp\ipykernel_37480\1770313285.py:16: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(

# %%
accidents['Latitude'] = accidents['Latitude'].fillna(accidents['Latitude'].mode()[0])
accidents['Longitude'] = accidents['Longitude'].fillna(accidents['Longitude'].mode()[0])
accidents['Road_Surface_Conditions'] = accidents['Road_Surface_Conditions'].fillna('unknown surface conditions')
accidents['Road_Type'] = accidents['Road_Type'].fillna('unaccounted')
accidents['Weather_Conditions'] = accidents['Weather_Conditions'].fillna('unaccounted weather conditions')
accidents['Urban_or_Rural_Area'] = accidents['Urban_or_Rural_Area'].fillna(accidents['Urban_or_Rural_Area'].mode()[0])

# %% [markdown]
# <h1> Insight 12: Changing category types </h1>

# %%
accidents['Accident_Severity'] = accidents['Accident_Severity'].astype('category')
accidents['Latitude'] = accidents['Latitude'].astype('category')
accidents['Longitude'] = accidents['Longitude'].astype('category')
accidents['Light_Conditions'] = accidents['Light_Conditions'].astype('category')
accidents['District Area'] = accidents['District Area'].astype('category')
accidents['Road_Surface_Conditions'] = accidents['Road_Surface_Conditions'].astype('category')
accidents['Road_Type'] = accidents['Road_Type'].astype('category')
accidents['Urban_or_Rural_Area'] = accidents['Urban_or_Rural_Area'].astype('category')
accidents['Weather_Conditions'] = accidents['Weather_Conditions'].astype('category')
accidents['Vehicle_Type'] = accidents['Vehicle_Type'].astype('category')

# %% [markdown]
# <h1> Insight 13: Which road type helds more accidents? </h1>

# %%
accidents['Road_Type'].count()
# Out:
# 660679

# %%
accidents['Road_Type'].value_counts()
# Out:
# Road_Type
# Single carriageway    492143
# Dual carriageway       99424
# Roundabout             43992
# One way street         13559
# Slip road               7041
# unaccounted             4520
# Name: count, dtype: int64

# %% [markdown]
# <h1>Insight 14: Commong weather condition when accidents happen? </h1>

# %%
accidents['Weather_Conditions'].value_counts()
# Out:
# Weather_Conditions
# Fine no high winds                520885
# Raining no high winds              79696
# Other                              17150
# unaccounted weather conditions     14128
# Raining + high winds                9615
# Fine + high winds                   8554
# Snowing no high winds               6238
# Fog or mist                         3528
# Snowing + high winds                 885
# Name: count, dtype: int64

# %% [markdown]
# <h1> Insight 15: On 2019, upon clsoer examination of the vehicle type of accidents and most of the accident was in the vehicle</h1>

# %%
accidents['Light_Conditions'].value_counts()
# Out:
# Light_Conditions
# Daylight                       484880
# Darkness - lights lit          129335
# Darkness - no lighting          37437
# Darkness - lighting unknown      6484
# Darkness - lights unlit          2543
# Name: count, dtype: int64

# %%
accidents['Vehicle_Type'].value_counts()
# Out:
# Vehicle_Type
# Car                                      497992
# Van / Goods 3.5 tonnes mgw or under       34160
# Bus or coach (17 or more pass seats)      25878
# Motorcycle over 500cc                     25657
# Goods 7.5 tonnes mgw and over             17307
# Motorcycle 125cc and under                15269
# Taxi/Private hire car                     13294
# Motorcycle over 125cc and up to 500cc      7656
# Motorcycle 50cc and under                  7603
# Goods over 3.5t. and under 7.5t            6096
# Other vehicle                              5637
# Minibus (8 - 16 passenger seats)           1976
# Agricultural vehicle                       1947
# Pedal cycle                                 197
# Data missing or out of range                  6
# Ridden horse                                  4
# Name: count, dtype: int64

# %% [markdown]
# <h1> Insight 16 : Which district has the highest number of accidents?</h1>

# %%
accidents['District Area'].value_counts()
# Out:
# District Area
# Birmingham            13491
# Leeds                  8898
# Manchester             6720
# Bradford               6212
# Sheffield              5710
#                       ...
# Berwick-upon-Tweed      153
# Teesdale                142
# Shetland Islands        133
# Orkney Islands          117
# Clackmannanshire         91
# Name: count, Length: 422, dtype: int64

# %% [markdown]
# <h1> Insight 17: Accident severity counts within different weather conditions?</h1>

# %%
weather_severity = accidents.groupby('Weather_Conditions')['Accident_Severity'].value_counts().unstack().fillna(0)
#severe_weather = weather_severity['Severe'].sort_values(ascending=False)
# Out:
# C:\Users\there\AppData\Local\Temp\ipykernel_37480\2071551289.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   weather_severity = accidents.groupby('Weather_Conditions')['Accident_Severity'].value_counts().unstack().fillna(0)

# %%
weather_severity
# Out:
# Accident_Severity               Fatal  Serious  Slight
# Weather_Conditions
# Fine + high winds                 175     1245    7134
# Fine no high winds               7100    72046  441739
# Fog or mist                        82      483    2963
# Other                             165     1801   15184
# Raining + high winds              145     1261    8209
# Raining no high winds             848     9468   69380
# Snowing + high winds                3      109     773
# Snowing no high winds              36      565    5637
# unaccounted weather conditions    107     1239   12782

# %% [markdown]
# <h1> Insight 18 : How serious accidents happen depending on light conditions, road type, and weather conditions?</h1>

# %%
accidents[accidents['Accident_Severity'] == 'Serious'].count()
# Out:
# Index                      88217
# Accident_Severity          88217
# Accident Date              35293
# Latitude                   88217
# Light_Conditions           88217
# District Area              88217
# Longitude                  88217
# Number_of_Casualties       88217
# Number_of_Vehicles         88217
# Road_Surface_Conditions    88217
# Road_Type                  88217
# Urban_or_Rural_Area        88217
# Weather_Conditions         88217
# Vehicle_Type               88217
# Year                       35293
# dtype: int64

# %%
severe_conditions = accidents[accidents['Accident_Severity'] == 'Serious'].groupby(['Light_Conditions', 'Road_Type', 'Weather_Conditions']).size().reset_index(name='Count')
top_severe = severe_conditions.sort_values('Count', ascending=False)
# Out:
# C:\Users\there\AppData\Local\Temp\ipykernel_37480\2020964732.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   severe_conditions = accidents[accidents['Accident_Severity'] == 'Serious'].groupby(['Light_Conditions', 'Road_Type', 'Weather_Conditions']).size().reset_index(name='Count')

# %%
top_severe
# Out:
#             Light_Conditions           Road_Type  \
# 244                 Daylight  Single carriageway
# 82     Darkness - lights lit  Single carriageway
# 217                 Daylight    Dual carriageway
# 248                 Daylight  Single carriageway
# 190   Darkness - no lighting  Single carriageway
# ..                       ...                 ...
# 188   Darkness - no lighting          Roundabout
# 186   Darkness - no lighting          Roundabout
# 148  Darkness - lights unlit           Slip road
# 114  Darkness - lights unlit    Dual carriageway
# 133  Darkness - lights unlit          Roundabout
#
#                  Weather_Conditions  Count
# 244              Fine no high winds  41598
# 82               Fine no high winds  11056
# 217              Fine no high winds   6427
# 248           Raining no high winds   4188
# 190              Fine no high winds   4154
# ..                              ...    ...
# 188  unaccounted weather conditions      0
# ...

# %% [markdown]
# <h1> Insight 19: Based from the current records most serious accidents happen during daylight in a single carriageway road with a fine with no high winds, such conditions accounts to 47% of all serious accident conditions recorded How fatal does then Road Type and it's Surface Condition is?</h1>

# %%
surface_road_severity = accidents.groupby(['Road_Surface_Conditions', 'Road_Type', 'Accident_Severity']).size().sort_values(ascending=False).reset_index(name='Count')
# Out:
# C:\Users\there\AppData\Local\Temp\ipykernel_37480\1001075850.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   surface_road_severity = accidents.groupby(['Road_Surface_Conditions', 'Road_Type', 'Accident_Severity']).size().sort_values(ascending=False).reset_index(name='Count')

# %%
surface_road_severity
# Out:
#         Road_Surface_Conditions           Road_Type Accident_Severity   Count
# 0                           Dry  Single carriageway            Slight  279489
# 1                   Wet or damp  Single carriageway            Slight  117798
# 2                           Dry    Dual carriageway            Slight   56889
# 3                           Dry  Single carriageway           Serious   48873
# 4                           Dry          Roundabout            Slight   27955
# ..                          ...                 ...               ...     ...
# 103  unknown surface conditions          Roundabout             Fatal       0
# 104        Flood over 3cm. deep          Roundabout             Fatal       0
# 105  unknown surface conditions      One way street             Fatal       0
# 106                        Snow         unaccounted             Fatal       0
# 107                Frost or ice         unaccounted             Fatal       0
#
# [108 rows x 4 columns]

# %% [markdown]
# <h1> Insight 20: The most accidents happen in urban or rural areas? </h1>

# %%
urban_rural_counts = accidents['Urban_or_Rural_Area'].value_counts()
urban_rural_counts.plot(
    kind = 'pie',
    colors = ['green','red'],
    figsize = (6,6),
    title = 'Urban vs Rural Accidents'
)

plt.ylabel("")
plt.show()

# %%
Accident_Severity_counts = accidents['Road_Surface_Conditions'].value_counts()
Accident_Severity_counts.plot(
    kind = 'pie',
    colors = ['green','blue'],
    figsize = (6,6),
    title = 'Urban vs Rural Accidents'
)

plt.ylabel("")
plt.show()

# %%
accidents ['Latitude'].value_counts().plot(kind='bar')
plt.title("Accidents by Road Type")
plt.xlabel("Road Type")
plt.ylabel("Number of Accidents")
plt.show()

# %% [markdown]
# <h1> Insight 21: What do this chart imply about the risks of different vehicles?</h1>

# %%
light_counts = accidents['Light_Conditions'].value_counts()

light_counts.plot(
    kind='bar',
    color=['violet','green','blue'],
    figsize=(8,5),
    title='Accidents by Light Conditions'
)

plt.xlabel("Light Condition")
plt.ylabel("Number of Accidents")
plt.grid(axis='y', alpha=0.5)
plt.show()

# %%
vehicle_counts = accidents['Vehicle_Type'].value_counts()
vehicle_counts.plot(
    kind = 'barh',
    color = ['blue'],
    figsize = (8,5),
    title = 'Top Vehicles Types Involved in Accidents'
)

plt.xlabel("Accidents Date")
plt.ylabel("Vehicle Type")
plt.grid(axis='x', alpha=0.5)
plt.show()
